# %%
#Importing the libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Importing the data
dataset = pd.read_csv(r'C:\Users\ayushsingh\OneDrive - Sopra Steria\Desktop\Machine Learning\Data Analyst\Finance_data.csv')

# %%
#Checking for the datasets columns
dataset.head()
# Out:
#    Gender  Age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
#Getting the info of datasets whether any columns have any null data and dataset column Dtype
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Gender                             40 non-null     object
#  1   Age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Market                       40 non-null     object
# ...

# %%
#Plotting the boxplot to check which gender do the investements
sns.boxplot(x="Gender",y="Age",data=dataset)
plt.show()

# %%
#Dropping the null values
dataset.dropna()
# Out:
#     Gender  Age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
#Dropping the Equilty Market Column
dataset.drop(["Equity_Market"],axis=1,inplace=True)

# %%
dataset.head()
# Out:
#    Gender  Age Investment_Avenues  Mutual_Funds  Debentures  Government_Bonds  \
# 0  Female   34                Yes             1           5                 3
# 1  Female   23                Yes             4           2                 1
# 2    Male   30                Yes             3           4                 2
# 3    Male   22                Yes             2           3                 7
# 4  Female   24                 No             2           3                 6
#
#    Fixed_Deposits  PPF  Gold Stock_Market  ...           Duration  \
# 0               7    6     4          Yes  ...          1-3 years
# 1               5    6     7           No  ...  More than 5 years
# 2               5    1     7          Yes  ...          3-5 years
# 3               6    4     5          Yes  ...   Less than 1 year
# 4               4    5     7           No  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
#dropping the columns
dataset.drop(["Debentures","Government_Bonds"],axis=1,inplace=True)

# %%
dataset.head()
# Out:
#    Gender  Age Investment_Avenues  Mutual_Funds  Fixed_Deposits  PPF  Gold  \
# 0  Female   34                Yes             1               7    6     4
# 1  Female   23                Yes             4               5    6     7
# 2    Male   30                Yes             3               5    1     7
# 3    Male   22                Yes             2               6    4     5
# 4  Female   24                 No             2               4    5     7
#
#   Stock_Market          Factor             Objective  ...           Duration  \
# 0          Yes         Returns  Capital Appreciation  ...          1-3 years
# 1           No  Locking Period  Capital Appreciation  ...  More than 5 years
# 2          Yes         Returns  Capital Appreciation  ...          3-5 years
# 3          Yes         Returns                Income  ...   Less than 1 year
# 4           No         Returns                Income  ...   Less than 1 year
#
# ...

# %%
#dropping the columns
dataset.drop(["Fixed_Deposits","PPF","Gold"],axis=1,inplace=True)

# %%
dataset.head()
# Out:
#    Gender  Age Investment_Avenues  Mutual_Funds Stock_Market          Factor  \
# 0  Female   34                Yes             1          Yes         Returns
# 1  Female   23                Yes             4           No  Locking Period
# 2    Male   30                Yes             3          Yes         Returns
# 3    Male   22                Yes             2          Yes         Returns
# 4  Female   24                 No             2           No         Returns
#
#               Objective          Purpose           Duration Invest_Monitor  \
# 0  Capital Appreciation  Wealth Creation          1-3 years        Monthly
# 1  Capital Appreciation  Wealth Creation  More than 5 years         Weekly
# 2  Capital Appreciation  Wealth Creation          3-5 years          Daily
# 3                Income  Wealth Creation   Less than 1 year          Daily
# 4                Income  Wealth Creation   Less than 1 year          Daily
#
# ...

# %%
#Plotting the investment_avenue and stock market graph 
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(x=dataset["Gender"],hue=dataset["Investment_Avenues"]) # Single value can be passed in counterplot x,y
plt.title("Investment_Avenues")
plt.show()


plt.figure(figsize=(12,6))
plt.subplot(1,2,2)
sns.countplot(x=dataset["Gender"],hue=dataset["Stock_Market"])
plt.title("Stock Market")
plt.show()

# %%
plt.figure(figsize= (18,6))
plt.subplot(1,2,1)
sns.countplot(hue = dataset['Gender'], x = dataset['Duration'], palette = 'viridis', linewidth = 2, edgecolor = "black" )
plt.title("DURATION")

plt.subplot(1,2,2)
sns.countplot(hue = dataset["Gender"], x = dataset["Invest_Monitor"], palette = "seismic", linewidth = 2, edgecolor ="black")
plt.title("INVESTMENT MONITORING")
plt.show()
